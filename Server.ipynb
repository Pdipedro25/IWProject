# %% [markdown]
# # Server

# %%
import socket                   # Import socket module

HEADERSIZE = 40
port = 60000                    # Reserve a port for your service.
s = socket.socket()             # Create a socket object
host = socket.gethostname()     # Get local machine name
s.bind((host, port))            # Bind to the port
s.listen(5)                     # Now wait for client connection.

print ('Server listening....')

while True:
    conn, addr = s.accept()     # Establish connection with client.
    print ('Got connection from', addr)
    
    header = conn.recv(HEADERSIZE)
    
    filename = './ReceivedImages/' + header.decode()
    
    
    with open(filename, 'wb') as f:
        print ('file opened')
        
        while True:
            print('receiving data...')
            data = conn.recv(1024)
            
            if not data:
                break
             # write data to a file
            f.write(data)

    f.close()
    print('Successfully get the file')
    conn.close()
# Out:
# Server listening....
# Got connection from ('172.21.35.71', 59776)
# file opened
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# receiving data...
# Successfully get the file
